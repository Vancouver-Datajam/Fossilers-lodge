# %%
--select * from Country_Budgets_Combined_Details limit 10;

--select * from COUNTRY_BUDGETS_SUMMARY limit 10;

select * from COUNTRY_PRIVATE_SUMMARY limit 10;

--select * from INDICS limit 10;

--select * from PERGDP limit 10;

--select * from REGION_BUDGETS limit 10;

# %% [markdown]
# **Exploring Data Tables**

# %%
SELECT PRODUCT
FROM COUNTRY_BUDGETS_SUMMARY
GROUP BY PRODUCT
LIMIT 100;

# %%
SELECT FLOW
FROM COUNTRY_PRIVATE_SUMMARY
GROUP BY FLOW
LIMIT 100;

# %%
SELECT PRODUCT
FROM COUNTRY_PRIVATE_SUMMARY
GROUP BY PRODUCT
LIMIT 100;

# %%
SELECT COUNTRY
FROM COUNTRY_PRIVATE_SUMMARY
GROUP BY COUNTRY
LIMIT 100;

# %%
SELECT COUNTRY
FROM COUNTRY_BUDGETS_SUMMARY
GROUP BY COUNTRY
LIMIT 100;

# %%
SELECT FLOW
FROM COUNTRY_BUDGETS_SUMMARY
GROUP BY FLOW
LIMIT 100;

# %% [markdown]
# **EXPLORING CANADIAN FUEL VS RENEWABLE INVESTMENTS FROM 2015**

# %%
SELECT VALUE, TIME, 
FROM COUNTRY_BUDGETS_SUMMARY
WHERE TIME > 2015
AND COUNTRY =  'CANADA' 
AND PRODUCT = 'RDDUSD'
AND FLOW  IN ('FOSSILFUEL')
--AND FLOW  IN ('RENEWABLE') 
ORDER BY TIME DESC;
